# %%
import easyocr
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image

CARD_COORDS = {'name': (348.0, 46.0), 
               'power': (592.5, 119.0), 
               'attack': (238.0, 743.0), 
               'defense': (352.0, 743.0), 
               'health': (467.0, 744.0), 
               'level': (102.0, 702.0), 
               'skill_level': (269.0, 868.0)}

target_card_size = (691, 1099)
target_schreenshot_size = (1242, 1824)

# %%
img_path = './downloaded_images/'
reader = easyocr.Reader(['en'], gpu=True)

# %%
img = cv2.imread(img_path+'Acidfire.png')
img = cv2.resize(img, target_card_size)
res = reader.readtext(img)
for detection in res:
    top_left = tuple([int(val) for val in detection[0][0]])
    bottom_right = tuple([int(val) for val in detection[0][2]])
    text = detection[1]
    font = cv2.FONT_HERSHEY_SIMPLEX
    img = cv2.rectangle(img, top_left, bottom_right, (0,255,0), 5)
for key, value in CARD_COORDS.items():
    plt.scatter(value[0], value[1], c='r')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()
print(f'size of image: {img.shape}')
# Out:
# size of image: (1099, 691, 3)

# %%
img = cv2.imread(img_path+'Acidfire.png')
img = cv2.resize(img, target_card_size)
res = reader.readtext(img)
for detection in res:
    top_left = tuple([int(val) for val in detection[0][0]])
    bottom_right = tuple([int(val) for val in detection[0][2]])
    text = detection[1]
    font = cv2.FONT_HERSHEY_SIMPLEX
    img = cv2.rectangle(img, top_left, bottom_right, (0,255,0), 5)
for key, value in CARD_COORDS.items():
    plt.scatter(value[0], value[1], c='r')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()
print(f'size of image: {img.shape}')
# Out:
# size of image: (1099, 691, 3)

# %%
img = cv2.imread(img_path+'Aegir.png')
img = cv2.resize(img, target_card_size)
res = reader.readtext(img)
for detection in res:
    top_left = tuple([int(val) for val in detection[0][0]])
    bottom_right = tuple([int(val) for val in detection[0][2]])
    text = detection[1]
    font = cv2.FONT_HERSHEY_SIMPLEX
    img = cv2.rectangle(img, top_left, bottom_right, (0,255,0), 5)
for key, value in CARD_COORDS.items():
    plt.scatter(value[0], value[1], c='r')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()
print(f'size of image: {img.shape}')
# Out:
# size of image: (1099, 691, 3)

# %%
img = cv2.imread(img_path+'Bane.png')
img = cv2.resize(img, target_card_size)
res = reader.readtext(img)
for detection in res:
    top_left = tuple([int(val) for val in detection[0][0]])
    bottom_right = tuple([int(val) for val in detection[0][2]])
    text = detection[1]
    font = cv2.FONT_HERSHEY_SIMPLEX
    img = cv2.rectangle(img, top_left, bottom_right, (0,255,0), 5)
for key, value in CARD_COORDS.items():
    plt.scatter(value[0], value[1], c='r')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()
print(f'size of image: {img.shape}')
# Out:
# size of image: (1099, 691, 3)

# %%
img = cv2.imread(img_path+'Anzia.png')
img = cv2.resize(img, target_card_size)
res = reader.readtext(img)
for detection in res:
    top_left = tuple([int(val) for val in detection[0][0]])
    bottom_right = tuple([int(val) for val in detection[0][2]])
    text = detection[1]
    font = cv2.FONT_HERSHEY_SIMPLEX
    img = cv2.rectangle(img, top_left, bottom_right, (0,255,0), 5)
for key, value in CARD_COORDS.items():
    plt.scatter(value[0], value[1], c='r')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()
print(f'size of image: {img.shape}')
# Out:
# size of image: (1099, 691, 3)

# %%
new_path = './downloaded_images/Aconia'

new_path = new_path+".png"

reader = easyocr.Reader(['en'], gpu=True)
res = reader.readtext(new_path)
res_df = pd.DataFrame(res, columns = ['Detection', 'Text', 'Confidence'])

# %%
img = cv2.imread(new_path)
for detection in res:
    top_left = tuple([int(val) for val in detection[0][0]])
    bottom_right = tuple([int(val) for val in detection[0][2]])
    text = detection[1]
    font = cv2.FONT_HERSHEY_SIMPLEX
    img = cv2.rectangle(img, top_left, bottom_right, (0,255,0), 5)
coords_dict = {
    "name": (0 ,0),
    "power": (0 ,0),
    "attack": (0 ,0),
    "defense": (0 ,0),
    "health": (0 ,0),
    "level": (0 ,0),
    "skill_level": (0 ,0)
}
indexes = [0, 2, 13, 14, 15, 11, 20]
for i in indexes:
    coords = res[i][0]
    center_x = (coords[0][0] + coords[1][0]) / 2
    center_y = (coords[0][1] + coords[2][1]) / 2
    for k, v in coords_dict.items():
        if v == (0, 0):
            if k == "skill_level":
               center_x += 40
            coords_dict[k] = (center_x, center_y)
            break
        
    plt.scatter(center_x, center_y, color='red')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()
print(coords_dict)
# Out:
# {'name': (347.0, 45.0), 'power': (591.0, 115.0), 'attack': (238.0, 712.0), 'defense': (353.0, 714.0), 'health': (467.0, 712.0), 'level': (102.0, 672.0), 'skill_level': (279.0, 831.0)}

# %%
img = cv2.imread(img_path+'Morris.png')
img = cv2.resize(img, target_card_size)
res = reader.readtext(img)
for detection in res:
    top_left = tuple([int(val) for val in detection[0][0]])
    bottom_right = tuple([int(val) for val in detection[0][2]])
    text = detection[1]
    font = cv2.FONT_HERSHEY_SIMPLEX
    img = cv2.rectangle(img, top_left, bottom_right, (0,255,0), 5)
for key, value in CARD_COORDS.items():
    plt.scatter(value[0], value[1], c='r')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()
print(f'size of image: {img.shape}')
# Out:
# size of image: (1099, 691, 3)

# %%
import lectureCarte
new_path = './Images/hero6.jpg'
img = Image.open(new_path)
img = lectureCarte.resizeIm(img)
img = img.convert('RGB')
img = np.array(img)
reader = easyocr.Reader(['fr'], gpu=True)
res = reader.readtext(img)
res = [detection for detection in res if detection[2] >= 0.5]
for detection in res:
    top_left = tuple([int(val) for val in detection[0][0]])
    bottom_right = tuple([int(val) for val in detection[0][2]])
    text = detection[1]
    font = cv2.FONT_HERSHEY_SIMPLEX
    img = cv2.rectangle(img, top_left, bottom_right, (0,255,0), 5)

plt.figsize = (50, 50)    
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
new_path = './Images/hero3.jpg'
img = Image.open(new_path)
img = lectureCarte.resizeIm(img)
img = img.convert('RGB')
img = np.array(img)
reader = easyocr.Reader(['fr'], gpu=True)
res = reader.readtext(img)
res = [detection for detection in res if detection[2] >= 0.5]
for detection in res:
    top_left = tuple([int(val) for val in detection[0][0]])
    bottom_right = tuple([int(val) for val in detection[0][2]])
    text = detection[1]
    font = cv2.FONT_HERSHEY_SIMPLEX
    img = cv2.rectangle(img, top_left, bottom_right, (0,255,0), 5)
plt.figsize = (50, 50)    
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
new_path = './Images/hero7.jpg'
img = Image.open(new_path)
img = lectureCarte.resizeIm(img)
img = img.convert('RGB')
img = np.array(img)
reader = easyocr.Reader(['fr'], gpu=True)
res = reader.readtext(img)
res = [detection for detection in res if detection[2] >= 0.45]
for detection in res:
    top_left = tuple([int(val) for val in detection[0][0]])
    bottom_right = tuple([int(val) for val in detection[0][2]])
    text = detection[1]
    font = cv2.FONT_HERSHEY_SIMPLEX
    img = cv2.rectangle(img, top_left, bottom_right, (0,255,0), 5)

coords_dict = {
    "name": (0 ,0),
    "power": (0 ,0),
    "attack": (0 ,0),
    "defense": (0 ,0),
    "health": (0 ,0),
    "level": (0 ,0),
    "skill_level": (0 ,0)
}
indexes = [0, 2, 14, 15, 16, 12, 22]
for i in indexes:
    coords = res[i][0]
    center_x = (coords[0][0] + coords[1][0]) / 2
    center_y = (coords[0][1] + coords[2][1]) / 2
    for k, v in coords_dict.items():
        if v == (0, 0):
            coords_dict[k] = (center_x, center_y)
            break
    plt.scatter(center_x, center_y, color='red')

plt.figsize = (50, 50)    
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()
print(coords_dict)
# Out:
# {'name': (622.5, 74.0), 'power': (1046.5, 194.0), 'attack': (447.0, 1225.0), 'defense': (638.0, 1223.0), 'health': (829.0, 1222.0), 'level': (204.0, 1152.0), 'skill_level': (515.0, 1428.0)}

# %%
print(coords)

indexes_dict = {
    "name": 0,
    "power": 2,
    "attack": 14,
    "defense": 15,
    "health": 16,
    "level": 12,
    "skill_level": 22
}
# Out:
# [[483, 1409], [547, 1409], [547, 1447], [483, 1447]]

# %%
res_df = pd.DataFrame(res, columns = ['text', 'coordinates', 'confidence'])
res_df
# Out:
#                                                  text  \
# 0      [[520, 37], [725, 37], [725, 111], [520, 111]]
# 1    [[123, 171], [221, 171], [221, 239], [123, 239]]
# 2   [[968, 162], [1125, 162], [1125, 226], [968, 2...
# 3   [[964, 234], [1132, 234], [1132, 264], [964, 2...
# 4      [[93, 259], [249, 259], [249, 297], [93, 297]]
# 5      [[87, 291], [255, 291], [255, 329], [87, 329]]
# 6    [[112, 454], [228, 454], [228, 486], [112, 486]]
# 7   [[926, 896], [1148, 896], [1148, 928], [926, 9...
# 8   [[108, 1020], [200, 1020], [200, 1046], [108, ...
# 9   [[994, 984], [1080, 984], [1080, 1040], [994, ...
# 10  [[356, 1114], [414, 1114], [414, 1144], [356, ...
# 11  [[506, 1110], [751, 1110], [751, 1147], [506, ...
# 12  [[128, 1102], [280, 1102], [280, 1202], [128, ...
# 13  [[143, 1219], [259, 1219], [259, 1263], [143, ...
# 14  [[377, 1195], [517, 1195], [517, 1255], [377, ...
# 15  [[567, 1193], [709, 1193], [709, 1253], [567, ...
# ...

# %%
indexes = [0, 2, 14, 15, 16, 12, 22]

# %%
power_coords = res[2][0]
center_x = (power_coords[0][0] + power_coords[1][0]) / 2
center_y = (power_coords[0][1] + power_coords[2][1]) / 2

# %%
name_coords = res[0][0]
print(name_coords)
print(name_coords[0])
print(name_coords[1])
center_x = (name_coords[0][0] + name_coords[1][0]) / 2
center_y = (name_coords[0][1] + name_coords[2][1]) / 2
# Out:
# [[520, 37], [725, 37], [725, 111], [520, 111]]
# [520, 37]
# [725, 37]

# %%
new_path = './Images/hero8.jpg'
img = Image.open(new_path)
img = lectureCarte.resizeIm(img)
img = img.convert('RGB')
img = np.array(img)
reader = easyocr.Reader(['fr'], gpu=True)
res = reader.readtext(img)
for detection in res:
    top_left = tuple([int(val) for val in detection[0][0]])
    bottom_right = tuple([int(val) for val in detection[0][2]])
    text = detection[1]
    font = cv2.FONT_HERSHEY_SIMPLEX
    img = cv2.rectangle(img, top_left, bottom_right, (0,255,0), 5)
for k, v in coords_dict.items():
    plt.scatter(v[0], v[1], color='red')
plt.figsize = (50, 50)    
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
new_path = './Images/hero9.jpg'
img = Image.open(new_path)
img = lectureCarte.resizeIm(img)
img = img.convert('RGB')
img = np.array(img)
reader = easyocr.Reader(['fr'], gpu=True)
res = reader.readtext(img)
for detection in res:
    top_left = tuple([int(val) for val in detection[0][0]])
    bottom_right = tuple([int(val) for val in detection[0][2]])
    text = detection[1]
    font = cv2.FONT_HERSHEY_SIMPLEX
    img = cv2.rectangle(img, top_left, bottom_right, (0,255,0), 5)
for k, v in coords_dict.items():
    plt.scatter(v[0], v[1], color='red')
plt.figsize = (50, 50)    
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
res_df = pd.DataFrame(res, columns = ['text', 'coordinates', 'confidence'])
res_df
# Out:
#                                                  text  \
# 0      [[529, 41], [721, 41], [721, 107], [529, 107]]
# 1    [[139, 169], [205, 169], [205, 245], [139, 245]]
# 2   [[984, 166], [1110, 166], [1110, 222], [984, 2...
# 3   [[964, 234], [1130, 234], [1130, 264], [964, 2...
# 4      [[91, 259], [251, 259], [251, 299], [91, 299]]
# 5      [[86, 289], [257, 289], [257, 334], [86, 334]]
# 6    [[112, 454], [228, 454], [228, 486], [112, 486]]
# 7    [[104, 596], [238, 596], [238, 628], [104, 628]]
# 8    [[177, 671], [235, 671], [235, 707], [177, 707]]
# 9      [[92, 706], [248, 706], [248, 734], [92, 734]]
# 10     [[94, 730], [246, 730], [246, 760], [94, 760]]
# 11  [[925, 896], [1146, 896], [1146, 926], [925, 9...
# 12  [[960, 922], [1114, 922], [1114, 948], [960, 9...
# 13  [[108, 1020], [202, 1020], [202, 1048], [108, ...
# 14  [[996, 984], [1078, 984], [1078, 1040], [996, ...
# 15  [[356, 1114], [414, 1114], [414, 1144], [356, ...
# ...
